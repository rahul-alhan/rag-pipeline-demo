# %% [markdown]
# # RAG Pipeline Demo
# End-to-end walkthrough: ingest → retrieve → answer → evaluate.

# %%
import os
from dotenv import load_dotenv
load_dotenv()
assert os.getenv('OPENAI_API_KEY'), 'Set OPENAI_API_KEY first.'

# %% [markdown]
# ## 1. Build the index

# %%
from src.ingest import build_index
build_index(docs_dir='../docs', persist_dir='../chroma_db')

# %% [markdown]
# ## 2. Ask a question

# %%
from src.pipeline import answer
result = answer('What are the copyright escalation rules?')
print(result.answer)
print('\nSources:', result.sources)

# %% [markdown]
# ## 3. Run the eval gate

# %%
from src.evaluate import run_eval, check_gates
scores = run_eval('../eval/eval_set.json')
scores

# %%
passed, failures = check_gates(scores)
print('PASSED' if passed else 'FAILED', failures)
